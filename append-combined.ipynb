# %%
import pandas as pd
import numpy as np
import random
import os
import csv
df_csv_append=pd.DataFrame()

# %%
csv_path=os.path.join("cb_05_01.csv")
org_df=pd.read_csv(csv_path)
org_df.head(10)
# Out:
# C:\Users\chaoh\AppData\Local\Temp\ipykernel_20832\499226871.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   org_df=pd.read_csv(csv_path)
#             ride_id  rideable_type           started_at             ended_at  \
# 0  FE6A074FC945A086  electric_bike  2024-05-01 08:05:53  2024-05-01 08:15:14
# 1  6844CF42F72827D7   classic_bike  2024-05-10 15:00:06  2024-05-10 15:08:58
# 2  D7C9E007F791A7A2   classic_bike  2024-05-06 12:28:39  2024-05-06 12:35:21
# 3  3419650E2F5999F1   classic_bike  2024-05-16 16:09:14  2024-05-16 16:14:20
# 4  5469FDC75E0F1FCA  electric_bike  2024-05-29 15:43:37  2024-05-29 15:49:27
# 5  771438887ADBA23D  electric_bike  2024-05-10 17:25:27  2024-05-10 17:41:38
# 6  8D0709918C276FDC   classic_bike  2024-05-31 16:12:47  2024-05-31 16:40:34
# 7  B4ECBEB2D12AE451  electric_bike  2024-05-28 14:20:27  2024-05-28 14:22:11
# 8  1265629F414BCE14  electric_bike  2024-05-31 12:38:42  2024-05-31 12:42:42
# ...

# %%
#read all data set 1-5
df1=pd.read_csv('cb_05_01.csv')
df2=pd.read_csv('cb_05_02.csv')
df3=pd.read_csv('cb_05_03.csv')
df4=pd.read_csv('cb_05_04.csv')
df5=pd.read_csv('cb_05_05.csv')

combined_df = pd.concat([df1,df2, df3, df4, df5], ignore_index=True)
combined_df.to_csv('combined.csv',index=False)
# Out:
# C:\Users\chaoh\AppData\Local\Temp\ipykernel_20832\1862456302.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('cb_05_01.csv')
# C:\Users\chaoh\AppData\Local\Temp\ipykernel_20832\1862456302.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv('cb_05_02.csv')
# C:\Users\chaoh\AppData\Local\Temp\ipykernel_20832\1862456302.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3=pd.read_csv('cb_05_03.csv')
# C:\Users\chaoh\AppData\Local\Temp\ipykernel_20832\1862456302.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4=pd.read_csv('cb_05_04.csv')
# C:\Users\chaoh\AppData\Local\Temp\ipykernel_20832\1862456302.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
print(combined_df.dtypes)
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
## Count rider id
#count_ride_id=combined_df["ride_id"].value_counts()
#count_ride_id_df=pd.DataFrame(count_ride_id,items(),column=["unique_values","Counts"])
#count_ride_id_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 count_ride_id=combined_df["ride_id"].value_counts()
# ----> 2 count_ride_id_df=pd.DataFrame(count_ride_id,items(),column=["unique_values","Counts"])
#       3 count_ride_id_df
#
# NameError: name 'items' is not defined

# %%
#Take random sample
sample_size=150000
sample_data=combined_df.sample(n=sample_size)
sample_data.head(10)
# Out:
#                   ride_id  rideable_type           started_at  \
# 2509571  1E0471B13578A5CB   classic_bike  2024-05-25 18:54:58
# 3015726  751BD2919F855099  electric_bike  2024-05-08 17:15:13
# 3875460  A327924D8296E37F  electric_bike  2024-05-17 10:39:35
# 4191239  D957A9E5AEE5E932   classic_bike  2024-05-13 14:40:03
# 2029805  31AF04369A04A428  electric_bike  2024-05-08 15:33:46
# 3399156  79510DCCFD095138  electric_bike  2024-05-14 07:16:41
# 3503620  824E859FCF5042CC   classic_bike  2024-05-12 17:56:38
# 384857   11429ADF9B3F18C1  electric_bike  2024-05-06 16:56:43
# 2693340  0986B0C104510167   classic_bike  2024-05-25 15:25:45
# 2187274  404F63DEE1AAA76D   classic_bike  2024-05-22 16:17:21
#
#                     ended_at           start_station_name start_station_id  \
# 2509571  2024-05-25 19:15:49              W 45 St & 8 Ave          6676.02
# 3015726  2024-05-08 17:26:20              E 44 St & 2 Ave          6422.09
# ...

# %%
sample_data.to_csv('cb05.csv',index=False)
